# %%
import jerry
import networkx as nx


graph = nx.grid_graph(dim=(5,5))

# Creating a list of tuples
node_list = list(graph.nodes())

edge_list = list(graph.edges())

# Calling the add function from the example module
# result = example.add(node_list, edge_list)


# result = jerry.kruskal(edge_list, len(node_list))


G = jerry.kruskal_graph(graph)


# # Printing the result

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.figure()

nx.draw(G, pos = {x:(x[0], x[1]) for x in graph.nodes()},  node_size = 50, node_shape ='s');

plt.show()
